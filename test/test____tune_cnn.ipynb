# %%
from tuner.tune_cnn import search_model
# Out:
# /home/fytroo/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# Using TensorFlow backend.

# %%
def data():
    from keras.utils import to_categorical
    from tuner.load_data import load_fromdir
    dataset_dir = 'original_dataset/brain'
    resize=96
    x_train, y_train = load_fromdir(os.path.join(dataset_dir, 'auged'), resize=resize)
    x_test, y_test = load_fromdir(os.path.join(dataset_dir, 'validation'), resize=resize)
    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)
    return x_train, x_test, y_train, y_test

# %%
search_model(data)
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     import os
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from hyperopt import hp
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform, conditional
# except:
#     pass
#
# try:
#     from tuner import net
# except:
#     pass
#
# try:
#     import json
# except:
#     pass
#
# try:
#     import tensorflow as tf
# except:
#     pass
#
# try:
#     import keras
# except:
#     pass
#
# try:
#     from keras import backend as K
# except:
#     pass
#
# try:
#     from keras.datasets import mnist
# except:
#     pass
#
# try:
#     from keras.layers import BatchNormalization, Flatten, Dense
# except:
#     pass
#
# try:
#     from keras.layers import Input, Conv2D, Convolution2D
# except:
#     pass
#
# try:
#     from keras.layers import Activation, concatenate, Dropout
# except:
#     pass
#
# try:
#     from keras.layers import AveragePooling2D, GlobalAveragePooling2D, MaxPooling2D
# except:
#     pass
#
# try:
#     from keras.models import Sequential, Model
# except:
#     pass
#
# try:
#     from keras.utils import np_utils, to_categorical
# except:
#     pass
#
# try:
#     from keras.applications.imagenet_utils import _obtain_input_shape
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'ch': hp.choice('ch', [16, 32]),
#         'ch_1': hp.choice('ch_1', [32, 64]),
#     }
#
# >>> Data
#   1:
#   2: from keras.utils import to_categorical
#   3: from tuner.load_data import load_fromdir
#   4: dataset_dir = 'original_dataset/brain'
#   5: resize=96
#   6: x_train, y_train = load_fromdir(os.path.join(dataset_dir, 'auged'), resize=resize)
#   7: x_test, y_test = load_fromdir(os.path.join(dataset_dir, 'validation'), resize=resize)
#   8: y_train = to_categorical(y_train)
#   9: y_test = to_categorical(y_test)
#  10:
#  11:
#  12:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:     n_out = y_train.shape[-1]
#    4:     input_shape = (96, 96, 3)
#    5:     batch_size = 32
#    6:     epochs = 100
#    7:     steps_per_epoch = len(x_train) // batch_size
#    8:     lossfun = 'categorical_crossentropy'
#    9:     optimizer = 'Adam'
#   10:     metrics = ['accuracy']
#   11:
#   12:     inputs = Input(shape=input_shape)
#   13:     x = inputs
#   14:     ch = space['ch']
#   15:     x = Conv2D(ch, (3, 3))(x)
#   16:     x = Conv2D(ch, (3, 3))(x)
#   17:     x = Activation('relu')(x)
#   18:     x = MaxPooling2D(pool_size=(2, 2))(x)
#   19:     ch = space['ch_1']
#   20:     x = Conv2D(ch, (3, 3))(x)
#   21:     x = Conv2D(ch, (3, 3))(x)
#   22:     x = Activation('relu')(x)
#   23:     x = MaxPooling2D(pool_size=(2, 2))(x)
#   24:     x = Dropout(0.25)(x)
#   25:     x = Flatten()(x)
#   26:     x = Dense(512)(x)
#   27:     x = Activation('relu')(x)
#   28:     x = Dropout(0.5)(x)
#   29:     x = Dense(n_out)(x)
#   30:     x = Activation('softmax')(x)
#   31:     model = Model(inputs=inputs, outputs=x)
#   32:     model.compile(loss=lossfun, optimizer=optimizer, metrics=metrics)
#   33:     model.fit(
#   34:         x_train, y_train,
#   35:         batch_size=batch_size,
#   36:         epochs=epochs,
#   37:         verbose=2,
#   38:         validation_data=(x_test, y_test))
#   39:     score, acc = model.evaluate(x_test, y_test, verbose=0)
#   40:     print('Test accuracy:', acc)
#   41:     return {'loss': -acc, 'status': STATUS_OK, 'model': model}
#   42:
# Unexpected error: <class 'IsADirectoryError'>
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-4-cef1202c95d2> in <module>()
# ----> 1 search_model(data)
#
# ~/anaconda3/lib/python3.6/site-packages/tuner/tune_cnn.py in search_model(data, result_file)
#      31         algo=tpe.suggest,
#      32         max_evals=10,
# ---> 33         trials=Trials(),
#      34     )
#      35
#
# ~/anaconda3/lib/python3.6/site-packages/hyperas/optim.py in minimize(model, data, algo, max_evals, trials, functions, rseed, notebook_name, verbose, eval_space, return_space)
#      65                                      full_model_string=None,
#      66                                      notebook_name=notebook_name,
# ---> 67                                      verbose=verbose)
#      68
#      69     best_model = None
#
# ~/anaconda3/lib/python3.6/site-packages/hyperas/optim.py in base_minimizer(model, data, functions, algo, max_evals, trials, rseed, full_model_string, notebook_name, verbose, stack)
#     102
#     103     try:
# --> 104         from temp_model import keras_fmin_fnct, get_space
#     105     except:
#     106         print("Unexpected error: {}".format(sys.exc_info()[0]))
#
# ~/tuner/test/temp_model.py in <module>()
#     102 dataset_dir = 'original_dataset/brain'
#     103 resize=96
# --> 104 x_train, y_train = load_fromdir(os.path.join(dataset_dir, 'auged'), resize=resize)
#     105 x_test, y_test = load_fromdir(os.path.join(dataset_dir, 'validation'), resize=resize)
#     106 y_train = to_categorical(y_train)
#
# ~/anaconda3/lib/python3.6/site-packages/tuner/load_data.py in load_fromdir(dataset_dir, label2id, resize, rescale)
#     121 def load_fromdir(dataset_dir, label2id=None, resize=RESIZE, rescale=1):
#     122     df = df_fromdir(dataset_dir)
# --> 123     x_data, y_data = load_fromdf(df, label2id=label2id, resize=resize, rescale=rescale)
#     124     return x_data, y_data
#     125
#
# ~/anaconda3/lib/python3.6/site-packages/tuner/load_data.py in load_fromdf(dataframe, label2id, resize, rescale)
#     110         f = row['path']
#     111
# --> 112         x = arr_fromf(f, resize=resize, rescale=rescale)
#     113         x_data.append(x)
#     114         y_data.append(y)
#
# ~/anaconda3/lib/python3.6/site-packages/tuner/load_data.py in arr_fromf(f, resize, rescale)
#     131 def arr_fromf(f, resize=RESIZE, rescale=1):
#     132     resize = resize if type(resize) is tuple else (resize, resize)
# --> 133     img = Image.open(f).resize(resize, Image.LANCZOS)
#     134     if f.endswith('png') or f.endswith('PNG'):
#     135         img = img.convert('RGB')
#
# ~/anaconda3/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2528
#    2529     if filename:
# -> 2530         fp = builtins.open(filename, "rb")
#    2531         exclusive_fp = True
#    2532
#
# IsADirectoryError: [Errno 21] Is a directory: 'original_dataset/brain/auged/MS/0'
