# %%
from tuner import use_hyperas
from tuner.dataset import ClassificationDataset, AugmentDataset
from tuner import net
# Out:
# /home/fytroo/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# Using TensorFlow backend.

# %%
brain = ClassificationDataset('tmp/brain')
brain = AugmentDataset(brain)

# %%
import Augmentor

# %%
Augmentor.Pipeline('tmp/brain')
# Out:
# Initialised with 266 image(s) found.
# Output directory set to tmp/brain/output.

# %%
brain.augment_dataset()
# Out:
# Processing MS105.jpg:   3%|▎         | 5/184 [00:00<00:06, 27.74 Samples/s]
# Initialised with 46 image(s) found.
# Output directory set to /home/fytroo/Tuner/dev/standard_datasets/5a66f4d3b037cb410dbe3b5b/train/MS/output.
# Processing PD022.jpg:   1%|          | 2/184 [00:00<00:10, 17.64 Samples/s]
# Initialised with 46 image(s) found.
# Output directory set to /home/fytroo/Tuner/dev/standard_datasets/5a66f4d3b037cb410dbe3b5b/train/PD/output.
# Processing N079.jpg:   5%|▌         | 10/184 [00:00<00:02, 58.11 Samples/s]
# Initialised with 79 image(s) found.
# Output directory set to /home/fytroo/Tuner/dev/standard_datasets/5a66f4d3b037cb410dbe3b5b/train/N/output.
# Processing PS070.jpg:   1%|          | 2/184 [00:00<00:11, 16.03 Samples/s]
# Initialised with 75 image(s) found.
# Output directory set to /home/fytroo/Tuner/dev/standard_datasets/5a66f4d3b037cb410dbe3b5b/train/PS/output.

# %%
best_condition, best_model = use_hyperas.exec_hyperas(
    brain.train_dir,
    brain.validation_dir,
    net.basic,
    epochs=10,
    rescale=1./255
)
# Out:
# def data():
#     train_dir = '/home/fytroo/Tuner/dev/standard_datasets/5a66f4d3b037cb410dbe3b5b/auged'
#     test_dir = '/home/fytroo/Tuner/dev/standard_datasets/5a66f4d3b037cb410dbe3b5b/validation'
#     resize = '96'
#     rescale = '0.00392156862745098'
#     df = load_data.df_fromdir_classed(train_dir)
#     x_train, y_train = load_data.load_fromdf(df, resize=resize, rescale=rescale)
#     df = load_data.df_fromdir_classed(test_dir)
#     x_test, y_test = load_data.load_fromdf(df, resize=resize, rescale=rescale)
#
#     y_train = to_categorical(y_train)
#     y_test = to_categorical(y_test)
#
#     return x_train, y_train, x_test, y_test
#
#          name label        handle  \
# 0   MS161.jpg    MS  MS/MS161.jpg
# 1   MS102.jpg    MS  MS/MS102.jpg
# 2   MS068.jpg    MS  MS/MS068.jpg
# 3   MS149.jpg    MS  MS/MS149.jpg
# 4   MS118.jpg    MS  MS/MS118.jpg
# 5   PD056.jpg    PD  PD/PD056.jpg
# 6   PD037.jpg    PD  PD/PD037.jpg
# 7   PD128.jpg    PD  PD/PD128.jpg
# 8   PD034.jpg    PD  PD/PD034.jpg
# 9   PD002.jpg    PD  PD/PD002.jpg
# 10   N140.jpg     N    N/N140.jpg
# 11   N155.jpg     N    N/N155.jpg
# 12   N050.jpg     N    N/N050.jpg
# 13   N135.jpg     N    N/N135.jpg
# 14   N096.jpg     N    N/N096.jpg
# 15  PS068.jpg    PS  PS/PS068.jpg
# 16  PS109.jpg    PS  PS/PS109.jpg
# 17  PS124.jpg    PS  PS/PS124.jpg
# 18  PS121.jpg    PS  PS/PS121.jpg
# 19   PS83.jpg    PS   PS/PS83.jpg
#
#                                                  path
# 0   /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 1   /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 2   /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 3   /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 4   /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 5   /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 6   /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 7   /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 8   /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 9   /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 10  /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 11  /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 12  /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 13  /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 14  /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 15  /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 16  /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 17  /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 18  /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# 19  /home/fytroo/Tuner/dev/standard_datasets/5a66f...
# >>> Imports:
# #coding=utf-8
#
# try:
#     import os
# except:
#     pass
#
# try:
#     import subprocess
# except:
#     pass
#
# try:
#     import json
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from hyperopt import hp
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform, conditional
# except:
#     pass
#
# try:
#     import tensorflow as tf
# except:
#     pass
#
# try:
#     import keras
# except:
#     pass
#
# try:
#     from keras import backend as K
# except:
#     pass
#
# try:
#     from keras.datasets import mnist
# except:
#     pass
#
# try:
#     from keras.layers import BatchNormalization, Flatten, Dense
# except:
#     pass
#
# try:
#     from keras.layers import Input, Conv2D, Convolution2D
# except:
#     pass
#
# try:
#     from keras.layers import Activation, concatenate, Dropout
# except:
#     pass
#
# try:
#     from keras.layers import AveragePooling2D, GlobalAveragePooling2D, MaxPooling2D
# except:
#     pass
#
# try:
#     from keras.models import Sequential, Model
# except:
#     pass
#
# try:
#     from keras.utils import np_utils, to_categorical
# except:
#     pass
#
# try:
#     from keras.applications.imagenet_utils import _obtain_input_shape
# except:
#     pass
#
# try:
#     import Augmentor
# except:
#     pass
#
# try:
#     from tuner import utils
# except:
#     pass
#
# try:
#     from tuner import load_data
# except:
#     pass
#
# try:
#     from tuner import net
# except:
#     pass
#
# try:
#     from hyperas_data import data
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'ch': hp.choice('ch', [16, 32]),
#         'ch_1': hp.choice('ch_1', [32, 64]),
#     }
#
# >>> Data
#   1:
#   2: train_dir = '/home/fytroo/Tuner/dev/standard_datasets/5a66f4d3b037cb410dbe3b5b/auged'
#   3: test_dir = '/home/fytroo/Tuner/dev/standard_datasets/5a66f4d3b037cb410dbe3b5b/validation'
#   4: resize = '96'
#   5: rescale = '0.00392156862745098'
#   6: df = load_data.df_fromdir_classed(train_dir)
#   7: x_train, y_train = load_data.load_fromdf(df, resize=resize, rescale=rescale)
#   8: df = load_data.df_fromdir_classed(test_dir)
#   9: x_test, y_test = load_data.load_fromdf(df, resize=resize, rescale=rescale)
#  10:
#  11: y_train = to_categorical(y_train)
#  12: y_test = to_categorical(y_test)
#  13:
#  14:
#  15:
#  16:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:     params = eval(open('tmp_params.json', 'r').read())
#    4:
#    5:     n_out = params['n_out']
#    6:     input_shape = tuple(params['input_shape'])
#    7:     batch_size = params['batch_size']
#    8:     epochs = params['epochs']
#    9:     lossfun = params['lossfun']
#   10:     optimizer = params['optimizer']
#   11:     metrics = ['accuracy']
#   12:
#   13:     inputs = Input(shape=input_shape)
#   14:     x = inputs
#   15:     ch = space['ch']
#   16:     x = Conv2D(ch, (3, 3))(x)
#   17:     x = Conv2D(ch, (3, 3))(x)
#   18:     x = Activation('relu')(x)
#   19:     x = MaxPooling2D(pool_size=(2, 2))(x)
#   20:
#   21:     ch = space['ch_1']
#   22:     x = Conv2D(ch, (3, 3))(x)
#   23:     x = Conv2D(ch, (3, 3))(x)
#   24:     x = Activation('relu')(x)
#   25:     x = MaxPooling2D(pool_size=(2, 2))(x)
#   26:     x = Dropout(0.25)(x)
#   27:     x = Flatten()(x)
#   28:     x = Dense(512)(x)
#   29:     x = Activation('relu')(x)
#   30:     x = Dropout(0.5)(x)
#   31:     x = Dense(n_out)(x)
#   32:     x = Activation('softmax')(x)
#   33:     model = Model(inputs=inputs, outputs=x)
#   34:     model.compile(
#   35:         loss='categorical_crossentropy',
#   36:         optimizer=keras.optimizers.rmsprop(lr=0.0001, decay=1e-6),
#   37:         metrics=['accuracy'])
#   38:     model.fit(
#   39:         x_train,
#   40:         y_train,
#   41:         batch_size=batch_size,
#   42:         epochs=epochs,
#   43:         verbose=2,
#   44:         validation_data=(x_test, y_test))
#   45:
#   46:     score, acc = model.evaluate(x_test, y_test, verbose=0)
#   47:     print('Test accuracy:', acc)
#   48:     return {'loss': -acc, 'status': STATUS_OK, 'model': model}
#   49:
# Train on 736 samples, validate on 20 samples
# Epoch 1/10
#  - 4s - loss: 1.3911 - acc: 0.2758 - val_loss: 1.3324 - val_acc: 0.3500
# Epoch 2/10
#  - 1s - loss: 1.2699 - acc: 0.4307 - val_loss: 1.2141 - val_acc: 0.4500
# Epoch 3/10
#  - 1s - loss: 1.0789 - acc: 0.5734 - val_loss: 1.1022 - val_acc: 0.4500
# Epoch 4/10
#  - 1s - loss: 0.9361 - acc: 0.5951 - val_loss: 1.0171 - val_acc: 0.5000
# Epoch 5/10
#  - 1s - loss: 0.7975 - acc: 0.6821 - val_loss: 1.0254 - val_acc: 0.4500
# Epoch 6/10
#  - 1s - loss: 0.6761 - acc: 0.7541 - val_loss: 1.1916 - val_acc: 0.5000
# Epoch 7/10
#  - 1s - loss: 0.6070 - acc: 0.7473 - val_loss: 1.0979 - val_acc: 0.3500
# Epoch 8/10
#  - 1s - loss: 0.5285 - acc: 0.7962 - val_loss: 1.2444 - val_acc: 0.3500
# Epoch 9/10
#  - 1s - loss: 0.4364 - acc: 0.8329 - val_loss: 1.1063 - val_acc: 0.5000
# Epoch 10/10
#  - 1s - loss: 0.4120 - acc: 0.8505 - val_loss: 1.1589 - val_acc: 0.6500
# Test accuracy: 0.649999976158
# Train on 736 samples, validate on 20 samples
# Epoch 1/10
#  - 1s - loss: 1.3960 - acc: 0.2785 - val_loss: 1.3604 - val_acc: 0.3000
# Epoch 2/10
#  - 0s - loss: 1.2810 - acc: 0.4171 - val_loss: 1.3372 - val_acc: 0.3500
# Epoch 3/10
#  - 0s - loss: 1.1396 - acc: 0.5353 - val_loss: 1.3035 - val_acc: 0.4000
# Epoch 4/10
#  - 0s - loss: 1.0070 - acc: 0.5802 - val_loss: 1.2799 - val_acc: 0.4000
# Epoch 5/10
#  - 0s - loss: 0.8590 - acc: 0.7092 - val_loss: 1.3630 - val_acc: 0.3000
# Epoch 6/10
#  - 0s - loss: 0.7220 - acc: 0.7310 - val_loss: 1.2348 - val_acc: 0.3000
# Epoch 7/10
#  - 0s - loss: 0.5998 - acc: 0.7921 - val_loss: 1.3193 - val_acc: 0.3000
# Epoch 8/10
#  - 0s - loss: 0.5245 - acc: 0.8111 - val_loss: 1.2546 - val_acc: 0.3500
# Epoch 9/10
#  - 0s - loss: 0.4342 - acc: 0.8601 - val_loss: 1.5816 - val_acc: 0.3000
# Epoch 10/10
#  - 0s - loss: 0.3647 - acc: 0.8859 - val_loss: 1.2584 - val_acc: 0.4000
# Test accuracy: 0.40000000596
# Train on 736 samples, validate on 20 samples
# Epoch 1/10
#  - 1s - loss: 1.3741 - acc: 0.3111 - val_loss: 1.3455 - val_acc: 0.4500
# Epoch 2/10
#  - 1s - loss: 1.2274 - acc: 0.4823 - val_loss: 1.2811 - val_acc: 0.4000
# Epoch 3/10
#  - 1s - loss: 1.0371 - acc: 0.5842 - val_loss: 1.2111 - val_acc: 0.3000
# Epoch 4/10
#  - 1s - loss: 0.8562 - acc: 0.6821 - val_loss: 1.1582 - val_acc: 0.3000
# Epoch 5/10
#  - 1s - loss: 0.6976 - acc: 0.7649 - val_loss: 1.2252 - val_acc: 0.4000
# Epoch 6/10
#  - 1s - loss: 0.5383 - acc: 0.8111 - val_loss: 1.1862 - val_acc: 0.4500
# Epoch 7/10
#  - 1s - loss: 0.4389 - acc: 0.8546 - val_loss: 1.4204 - val_acc: 0.5500
# Epoch 8/10
#  - 1s - loss: 0.3686 - acc: 0.8723 - val_loss: 1.2521 - val_acc: 0.5500
# Epoch 9/10
#  - 1s - loss: 0.3143 - acc: 0.9035 - val_loss: 1.2740 - val_acc: 0.4500
# Epoch 10/10
#  - 1s - loss: 0.2258 - acc: 0.9307 - val_loss: 1.3296 - val_acc: 0.5500
# Test accuracy: 0.550000011921
# Train on 736 samples, validate on 20 samples
# Epoch 1/10
#  - 1s - loss: 1.3673 - acc: 0.3247 - val_loss: 1.3659 - val_acc: 0.2500
# Epoch 2/10
#  - 1s - loss: 1.1981 - acc: 0.4905 - val_loss: 1.2864 - val_acc: 0.4500
# Epoch 3/10
#  - 1s - loss: 0.9400 - acc: 0.6481 - val_loss: 1.1427 - val_acc: 0.5000
# Epoch 4/10
#  - 1s - loss: 0.7233 - acc: 0.7255 - val_loss: 1.1769 - val_acc: 0.3500
# Epoch 5/10
#  - 1s - loss: 0.5985 - acc: 0.7704 - val_loss: 1.1942 - val_acc: 0.4500
# Epoch 6/10
#  - 1s - loss: 0.4663 - acc: 0.8274 - val_loss: 1.1524 - val_acc: 0.4500
# Epoch 7/10
#  - 1s - loss: 0.4161 - acc: 0.8519 - val_loss: 1.2314 - val_acc: 0.4000
# Epoch 8/10
#  - 1s - loss: 0.3178 - acc: 0.8899 - val_loss: 1.3003 - val_acc: 0.4500
# Epoch 9/10
#  - 1s - loss: 0.2730 - acc: 0.9117 - val_loss: 1.4116 - val_acc: 0.5000
# Epoch 10/10
#  - 1s - loss: 0.2094 - acc: 0.9375 - val_loss: 1.4652 - val_acc: 0.5000
# Test accuracy: 0.5
# Train on 736 samples, validate on 20 samples
# Epoch 1/10
#  - 1s - loss: 1.3781 - acc: 0.3057 - val_loss: 1.3717 - val_acc: 0.4000
# Epoch 2/10
#  - 1s - loss: 1.1956 - acc: 0.5190 - val_loss: 1.4398 - val_acc: 0.3500
# Epoch 3/10
#  - 1s - loss: 0.9939 - acc: 0.6182 - val_loss: 1.3179 - val_acc: 0.4500
# Epoch 4/10
#  - 1s - loss: 0.8107 - acc: 0.6861 - val_loss: 1.2012 - val_acc: 0.4500
# Epoch 5/10
#  - 1s - loss: 0.6444 - acc: 0.7690 - val_loss: 1.2415 - val_acc: 0.5500
# Epoch 6/10
#  - 1s - loss: 0.5387 - acc: 0.7989 - val_loss: 1.2120 - val_acc: 0.4000
# Epoch 7/10
#  - 1s - loss: 0.4411 - acc: 0.8478 - val_loss: 1.1352 - val_acc: 0.4500
# Epoch 8/10
#  - 1s - loss: 0.3940 - acc: 0.8641 - val_loss: 1.3129 - val_acc: 0.2500
# Epoch 9/10
#  - 1s - loss: 0.2847 - acc: 0.9130 - val_loss: 1.4261 - val_acc: 0.3000
# Epoch 10/10
#  - 1s - loss: 0.2486 - acc: 0.9293 - val_loss: 1.2035 - val_acc: 0.6000
# Test accuracy: 0.600000023842
# Train on 736 samples, validate on 20 samples
# Epoch 1/10
#  - 1s - loss: 1.4045 - acc: 0.2704 - val_loss: 1.3723 - val_acc: 0.3000
# Epoch 2/10
#  - 1s - loss: 1.3086 - acc: 0.3872 - val_loss: 1.3472 - val_acc: 0.3500
# Epoch 3/10
#  - 1s - loss: 1.1826 - acc: 0.4891 - val_loss: 1.3075 - val_acc: 0.3500
# Epoch 4/10
#  - 1s - loss: 1.0293 - acc: 0.5870 - val_loss: 1.2441 - val_acc: 0.3000
# Epoch 5/10
#  - 1s - loss: 0.8855 - acc: 0.6495 - val_loss: 1.1728 - val_acc: 0.5000
# Epoch 6/10
#  - 1s - loss: 0.7256 - acc: 0.7296 - val_loss: 1.1291 - val_acc: 0.4500
# Epoch 7/10
#  - 1s - loss: 0.6458 - acc: 0.7568 - val_loss: 1.0921 - val_acc: 0.5500
# Epoch 8/10
#  - 1s - loss: 0.5530 - acc: 0.7745 - val_loss: 1.2292 - val_acc: 0.5000
# Epoch 9/10
#  - 1s - loss: 0.4538 - acc: 0.8315 - val_loss: 1.3007 - val_acc: 0.4000
# Epoch 10/10
#  - 1s - loss: 0.4150 - acc: 0.8451 - val_loss: 1.1155 - val_acc: 0.6000
# Test accuracy: 0.600000023842
# Train on 736 samples, validate on 20 samples
# Epoch 1/10
#  - 1s - loss: 1.3875 - acc: 0.3111 - val_loss: 1.3550 - val_acc: 0.3500
# Epoch 2/10
#  - 1s - loss: 1.1982 - acc: 0.4810 - val_loss: 1.2231 - val_acc: 0.3000
# Epoch 3/10
#  - 1s - loss: 0.9482 - acc: 0.6209 - val_loss: 1.1954 - val_acc: 0.4000
# Epoch 4/10
#  - 1s - loss: 0.7647 - acc: 0.6889 - val_loss: 1.0709 - val_acc: 0.4500
# Epoch 5/10
#  - 1s - loss: 0.6395 - acc: 0.7582 - val_loss: 1.1125 - val_acc: 0.5000
# Epoch 6/10
#  - 1s - loss: 0.5266 - acc: 0.8043 - val_loss: 1.1084 - val_acc: 0.5500
# Epoch 7/10
#  - 1s - loss: 0.4393 - acc: 0.8519 - val_loss: 1.3497 - val_acc: 0.3500
# Epoch 8/10
#  - 1s - loss: 0.3543 - acc: 0.8696 - val_loss: 1.3028 - val_acc: 0.3500
# Epoch 9/10
#  - 1s - loss: 0.2938 - acc: 0.8940 - val_loss: 1.2856 - val_acc: 0.5500
# Epoch 10/10
#  - 1s - loss: 0.2547 - acc: 0.9171 - val_loss: 1.3540 - val_acc: 0.5000
# Test accuracy: 0.5
# Train on 736 samples, validate on 20 samples
# Epoch 1/10
#  - 1s - loss: 1.3975 - acc: 0.3030 - val_loss: 1.3618 - val_acc: 0.3000
# Epoch 2/10
#  - 1s - loss: 1.2827 - acc: 0.4321 - val_loss: 1.2996 - val_acc: 0.3500
# Epoch 3/10
#  - 1s - loss: 1.1284 - acc: 0.5312 - val_loss: 1.2243 - val_acc: 0.4000
# Epoch 4/10
#  - 1s - loss: 0.9726 - acc: 0.6291 - val_loss: 1.1420 - val_acc: 0.4500
# Epoch 5/10
#  - 1s - loss: 0.7760 - acc: 0.7500 - val_loss: 1.1418 - val_acc: 0.6000
# Epoch 6/10
#  - 1s - loss: 0.6805 - acc: 0.7541 - val_loss: 1.2529 - val_acc: 0.4000
# Epoch 7/10
#  - 1s - loss: 0.5747 - acc: 0.8030 - val_loss: 1.1497 - val_acc: 0.5500
# Epoch 8/10
#  - 1s - loss: 0.4953 - acc: 0.8179 - val_loss: 1.1057 - val_acc: 0.5000
# Epoch 9/10
#  - 1s - loss: 0.4069 - acc: 0.8709 - val_loss: 1.1691 - val_acc: 0.4500
# Epoch 10/10
#  - 1s - loss: 0.3649 - acc: 0.8723 - val_loss: 1.2028 - val_acc: 0.4500
# Test accuracy: 0.449999988079
# Train on 736 samples, validate on 20 samples
# Epoch 1/10
#  - 1s - loss: 1.3851 - acc: 0.2935 - val_loss: 1.3714 - val_acc: 0.2000
# Epoch 2/10
#  - 1s - loss: 1.2767 - acc: 0.4266 - val_loss: 1.2996 - val_acc: 0.4000
# Epoch 3/10
#  - 1s - loss: 1.0907 - acc: 0.5761 - val_loss: 1.2011 - val_acc: 0.4000
# Epoch 4/10
#  - 1s - loss: 0.8960 - acc: 0.6481 - val_loss: 1.1654 - val_acc: 0.4000
# Epoch 5/10
#  - 1s - loss: 0.7308 - acc: 0.7160 - val_loss: 1.1976 - val_acc: 0.4500
# Epoch 6/10
#  - 1s - loss: 0.6441 - acc: 0.7418 - val_loss: 1.0822 - val_acc: 0.5000
# Epoch 7/10
#  - 1s - loss: 0.5363 - acc: 0.7976 - val_loss: 1.1933 - val_acc: 0.4000
# Epoch 8/10
#  - 1s - loss: 0.4506 - acc: 0.8356 - val_loss: 1.2810 - val_acc: 0.5000
# Epoch 9/10
#  - 1s - loss: 0.4039 - acc: 0.8696 - val_loss: 1.2239 - val_acc: 0.4500
# Epoch 10/10
#  - 1s - loss: 0.3460 - acc: 0.8723 - val_loss: 1.2338 - val_acc: 0.4500
# Test accuracy: 0.449999988079
# Train on 736 samples, validate on 20 samples
# Epoch 1/10
#  - 1s - loss: 1.3935 - acc: 0.2908 - val_loss: 1.3725 - val_acc: 0.3000
# Epoch 2/10
#  - 1s - loss: 1.2442 - acc: 0.4660 - val_loss: 1.3856 - val_acc: 0.3000
# Epoch 3/10
#  - 1s - loss: 1.0611 - acc: 0.5503 - val_loss: 1.3949 - val_acc: 0.3000
# Epoch 4/10
#  - 1s - loss: 0.8927 - acc: 0.6712 - val_loss: 1.3338 - val_acc: 0.3000
# Epoch 5/10
#  - 1s - loss: 0.7477 - acc: 0.7323 - val_loss: 1.3148 - val_acc: 0.3000
# Epoch 6/10
#  - 1s - loss: 0.6219 - acc: 0.7690 - val_loss: 1.3163 - val_acc: 0.2500
# Epoch 7/10
#  - 1s - loss: 0.5126 - acc: 0.8302 - val_loss: 1.2310 - val_acc: 0.4500
# Epoch 8/10
#  - 1s - loss: 0.4062 - acc: 0.8614 - val_loss: 1.3430 - val_acc: 0.2500
# Epoch 9/10
#  - 1s - loss: 0.3274 - acc: 0.8981 - val_loss: 1.2330 - val_acc: 0.3000
# Epoch 10/10
#  - 1s - loss: 0.2973 - acc: 0.9212 - val_loss: 1.6311 - val_acc: 0.5500
# Test accuracy: 0.550000011921
